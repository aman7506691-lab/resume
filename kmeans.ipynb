# %% [markdown]
# <a href="https://colab.research.google.com/github/aman7506691-lab/resume/blob/main/kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.cluster import KMeans
import numpy as np

X = np.array([[1,2],[1,4],[1,0],[10,2]])

kmeans = KMeans(n_clusters=2)
kmeans.fit(X)

print(kmeans.labels_)
# Out:
# [1 1 1 0]
